# %%
import pandas as pd

file_path = '/workspaces/BlueTriangleA/skillathon/absenteeism_at_work_converted.csv'
data = pd.read_csv(file_path)

data.head(), data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       740 non-null    int64
#  1   ID                               740 non-null    float64
#  2   Reason for absence               740 non-null    float64
#  3   Day of the week                  740 non-null    float64
#  4   Month of absence                 740 non-null    float64
#  5   Seasons                          740 non-null    float64
#  6   Transportation expense           740 non-null    float64
#  7   Distance from Residence to Work  740 non-null    float64
#  8   Service time                     740 non-null    float64
#  9   Age                              740 non-null    int64
#  10  Work load Average/day            740 non-null    int64
#  11  Hit target                       740 non-null    float64
# ...

# %%
# Clean the dataset: Remove the unnecessary 'Unnamed: 0' column
data_cleaned = data.drop(columns=['Unnamed: 0'])

# Basic descriptive statistics to understand the spread and distribution of data
descriptive_stats = data_cleaned.describe()

# Analyzing correlations to understand relationships between features
correlations = data_cleaned.corr()

descriptive_stats, correlations
# Out:
# (               ID  Reason for absence  Day of the week  Month of absence  \
#  count  740.000000          740.000000       740.000000        740.000000
#  mean    18.017568           19.216216         6.324324          3.914865
#  std     11.021247            8.433406         3.436287          1.421675
#  min      1.000000            0.000000         0.000000          2.000000
#  25%      9.000000           13.000000         3.000000          3.000000
#  50%     18.000000           23.000000         6.000000          4.000000
#  75%     28.000000           26.000000         9.000000          5.000000
#  max     36.000000           28.000000        12.000000          6.000000
#
#            Seasons  Transportation expense  Distance from Residence to Work  \
#  count  740.000000              740.000000                       740.000000
#  mean     2.544595              221.329730                        29.631081
# ...
